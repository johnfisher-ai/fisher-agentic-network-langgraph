# %% [markdown]
# # Agentic Travel Partner Agent Network

# %% [markdown]
# ## Goals
# A multi-agent and MCP server network for Ofishal Partners would fundamentally transform how travel suppliers (hotels, vacation rentals, airlines) interact with the Online Travel Agency (OTA) platform. Instead of navigating static dashboards, partners would engage with a dynamic ecosystem of specialized AI agents that proactively collaborate to optimize revenue, enhance guest experiences, and streamline operations.
#
# **Ofishal** is a fictitious travel, planning, and booking company with the tagline "Your *Ofishal* Travel Partner".
#
# ## Core Business Values
# The core business value lies in:
#
# **Proactive Optimization:** Agents don't just report data; they suggest and execute actions (e.g., adjusting rates during a sudden demand spike).
#
# **Hyper-Personalization:** Tailoring strategies to the specific partner's size, location, and market segment.
#
# **Operational Efficiency:** Automating repetitive tasks like review responses and content updates.
#
# **Risk:** Score the risk of implementing the change. High risk requires a Human-in-the-Loop.

# %% [markdown]
# ## Agent Roles
#
# **Gatherer:** Primarily collects data from internal and external systems. E.g., a Scout Agent would look for events in your area (concerts, sports, construction); the Official Aviation Guide (OAG) would collect inbound airline traffic trends; and a Competitive Intelligence Agent would collect pricing trends, amenities, offerings, and bundles from your competitors.
#
# **Analyst:** Determines the significance of data collected using sound statistical data processing.
#
# **Strategist:** Synthesizes the Gatherer and Analyst inputs and provides a comprehensive plan to move Key Performance Indicators (KPIs) for your business. E.g., Average Daily Rate (to increase this you need to do x, y, z); Booking trends (to combat downtrends you need to bundle a family plan and update your content to include the following tags and filters to ensure high Search Engine Optimization).
#
# **Actionable:** If low risk, have the AI call appropriate MCPs and APIs to implement the Strategy (e.g., BookingRatesMCP, ContentManagerMCP, seoMCP, etc.).
#
# **Risk:** Determines the risk of the change on a scale of 1 to 10; anything above 7 requires a human-in-the-loop to approve the change via MCP and APIs, or a human manually implements the strategy.
#
# **HumanInTheLoop:** Interactive human data gathering, e.g., human response to YES/NO questions, value questions, etc.

# %% [markdown]
# ## Agents (In this prototype)
# **Revenue Strategist Agent**: Maximize revenue per available room (RevPAR) and occupancy by analyzing real-time market data and competitor rates.
#
# **Content and Visibility Agent**: Ensure the property listing is optimized for Ofishal sort algorithm and SEO, improving conversion rates.
#
# **Guest Experience and Reputation Agent**: Manages brand reputation by analyzing reviews, automating responses, and flagging service issues before they affect the partner's score.
#
# **Market Intelligence Scout Agent**:  Monitors macro-travel trends, flight capacity data, and local events to predict demand shifts before they happen.
#
# **Human Approval Agent**:  Manages human-in-the-loop interactions and responds accordingly.
#
# **Broker**: Acts as the intelligent interface between the human partner and the specialized agents.  The user does not need to *talk* to the agents individually; the user states high-level business problem, and the Broker decomposes the task and delegates it.

# %% [markdown]
# ### Revenue Strategist Agent Details
#
# **Role**: Maximizes RevPAR (Revenue Per Available Room) and occupancy by analyzing real-time market data and competitor rates.
#
# **Instructions**: You are an expert Revenue Manager. Your goal is to maximize booking revenue. Analyze current pricing against competitor sets, historical data, and demand forecasts. Always justify your pricing recommendations with data.
#
# **Potential Applications, APIs and MCP Servers**:
# - Ofishal Partner Central(OPC) API: To push rate updates and read current inventory.
# - Rate Gain / Online Travel Agency (OTA) Insight: For competitor rate shopping data.
# - Partner or Ofishal Property Management Systems (PMS): Orcale Opera, Cloudbeds; To check real-time availability.
#
# **Example Interaction**
#
# User Prompt: "My occupancy for the third weekend of October is only 40%. What should I do?"
#
# Agent Response: "I see a local festival 'Jazz on the Green' was just announced for that weekend, driving demand up by 20% in your area, yet your competitors have lowered rates by an average of $15."
#
# Action: I recommend lowering your ADR (Average Daily Rate) by 10% (from $200 to $180) to capture volume, then implementing a dynamic surge rule once occupancy hits 70%.
#
# Projected Outcome: This should increase occupancy to ~85% based on current velocity."

# %% [markdown]
# ### Content and Visibility Agent Details
#
# **Role**: Ensures the property listing is optimized for Ofishal’s sort algorithm and SEO, improving conversion rates.
#
# **Instructions**: You are a Digital Marketing Specialist for travel. Audit listing content for completeness, image quality, and keyword relevance. Monitor "Content Score" metrics and suggest improvements to boost visibility in search results.
#
# **Potential Applications, APIs and MCP Servers**:
# - Ofishal Content API: To update amenities, descriptions, and images.
# - Generative Image AI (e.g., Midjourney/DALL-E API): To suggest image framing or enhance lighting (virtual staging).
# - Google Trends: To identify trending travel keywords (e.g., "workcation," "pet-friendly").
#
# **Example Interaction**
#
# User Prompt: "Why is my listing appearing on page 2 for 'family suites'?"
#
# Agent Response: "Your 'Content Score' for family amenities is currently 65/100.
#
# Gap Analysis: You have 'cribs' listed in the text description but not tagged as a structured amenity, meaning the search filter misses you.
#
# Fix: I have drafted an update to tag 'Cribs/Infant Beds' and 'High Chair' in your amenities list. I also rewrote your room description to highlight 'spacious family living areas'. Shall I push these updates?"

# %% [markdown]
# ### Guest Experience & Reputation Agent Details
#
# **Role**: Manages brand reputation by analyzing reviews, automating responses, and flagging service issues before they affect the partner's score.
#
# **Instructions**: You are a Guest Relations Director. Monitor guest reviews and post-stay surveys. Draft empathetic, personalized responses to reviews. Identify recurring operational issues (e.g., "slow Wi-Fi") and alert management.
#
# **Potential Applications, APIs and MCP Servers**:
# - Ofishal Reviews API: To fetch and reply to reviews.
# - Sentiment Analysis Engine (e.g., NLP Cloud): To parse review text for sentiment.
# - Ticketing System (e.g., Zendesk/ServiceNow): To create maintenance tickets for recurring complaints.
#
# **Example Interaction**
#
# User Prompt: "Draft responses for the last 3 negative reviews."
#
# Agent Response: "Here are drafts for your approval:
# Review (2/5 stars): 'No hot water in the morning.' -> Draft: 'Dear Guest, we are truly sorry for the disruption. Our maintenance team has since replaced the boiler valve to ensure this doesn't happen again. We hope you give us another chance.'
#
# Note: I have also logged a 'High Priority' maintenance ticket regarding the boiler system in your internal log."

# %% [markdown]
# ### Market Intelligence Scout Agent Details
#
# **Role**: Monitors macro-travel trends, flight capacity data, and local events to predict demand shifts before they happen.
#
# **Instructions**: You are a Data Analyst. Scan global and local data sources for events, flight capacity changes, and travel restrictions. Correlate this with partner booking windows to predict demand anomalies.
#
# **Potential Applications, APIs and MCP Servers**:
# - OAG (Official Aviation Guide) / Cirium (Flight Data): To track inbound flight capacity.
# - OTP (On-time Performance): To align customers with best airlines
# - PredictHQ: For event tracking (concerts, conferences, sports).
# - Weather API: For seasonal forecasting.
#
# **Example Interaction**
#
# User Prompt: "Is there any inbound demand I should be aware of for Q1?"
#
# Agent Response: "Yes. Inbound flight capacity from the UK to your airport is increasing by 15% in February due to new direct routes."
# Insight: UK travelers tend to book 45+ days out.
# Recommendation: Create a 'Early Bird' package targeted at international stays of 5+ nights to capture this specific demographic.

# %% [markdown]
# ## Broker
#
# In an agentic network, the Broker (or "Orchestrator") acts as the intelligent interface between the human partner and the specialized agents. The user does not need to talk to the agents individually; they state a high-level business problem, and the Broker decomposes the task and delegates it.
#
# **Role**: Project Manager and Strategist. It understands the user's intent, breaks it down into sub-tasks, assigns them to the correct agents, synthesizes the results, and presents a cohesive business solution.
#
# **Instructions**:
#
# You are the Ofishal Partner Strategy Lead. Your goal is to solve complex business problems for partners.
# - *Analyze* the user's request.
# - *Delegate* sub-tasks to the Revenue Strategist, Content & Visibility, Guest Experience and Reputation, or Market Intelligence Scout agents.
# - *Wait* for their outputs.
# - *Synthesize* their findings into a single, actionable strategic plan.
# - *Ask* for permission to execute actions via the specialized agents.
#
# ### Collaboration Scenario: Low Season Slump
#
# **User Prompt to Broker**:
#
# "I'm worried about November. Bookings are pacing 20% behind last year. What is going on and how do we fix it?"
#
# **Step 1: Broker Decomposition & Delegation** The Broker analyzes the request and triggers three agents in parallel (hidden from user view):
#
# - To Market Scout: "Check specifically for demand drops or event cancellations in our region for November."
#
# - To Revenue Strategist: "Analyze our November rates vs. comp set. Are we overpriced?"
#
# - To Content Agent: "Check our listing visual appeal for 'Autumn/Winter' relevance."
#
# **Step 2: Agent Responses (Internal Network)**
#
# - Market Scout: "Major tech conference usually held in November moved to October. Demand is down, but leisure travel is steady."
#
# - Revenue Strategist: "We are priced at $250 (conference rates), but competitors have already dropped to $190 (leisure rates)."
#
# - Content Agent: "Our main photo still shows the pool, which is closed in November. We lack 'cozy' keywords."
#
# **Step 3: Broker Synthesis & Response** The Broker combines these isolated insights into a strategy.
#
# **Final Response to Partner**:
#
# "I have analyzed the situation and found the root cause. The Tech Summit moved to October, so we are missing that corporate demand. However, we can pivot to capture leisure travelers.
#
# **The Strategy**:
#
# - Pricing (Revenue Agent): You are currently priced for business travelers ($250). I recommend dropping rates to $195 to undercut the leisure market comp set.
#
# - Merchandising (Content Agent): Your main photo features the closed pool. I suggest swapping it for the 'Fireplace Lobby' image and updating the description to feature 'Autumn Getaways'.
#
# - Promotion (Market Scout): Since flight capacity from domestic hubs is stable, we should launch a 'Stay 3, Pay 2' campaign for weekenders.
#
# Shall I execute the rate change and photo swap for you now?"

# %% [markdown]
# **Sequence Flow Broker and Agents**
# ```markdown
#
# [USER] --> (Input: "Worried about bookings...")
# |
# v
# [BROKER AGENT] (Analyzes Intent -> Creates Execution Plan)
# |
# +--->   [Call 1: MARKET SCOUT] (Check for macro demand/events)
# |         |
# |         v
# |       {Returns: "Tech Summit Cancelled"}
# |
# +--->   [Call 2: REVENUE AGENT] (Check pricing vs. comps)
# |         |
# |         v
# |       {Returns: "Price Variance: +$60 vs Comps"}
# |
# +--->   [Call 3: CONTENT AGENT] (Check seasonal relevance)
#           |
#           V
#         {Returns: "Image Mismatch: Summer Pool"}
# |
# v
# [BROKER AGENT] (Synthesizes 3 inputs -> Formulates Strategy)
# |
# v
# [USER] <--(Output: "Strategy: Drop rate, swap photo, target leisure.")

# %% [markdown]
# ### Plan, work, solution ###
#
# **Phase 1: Broker Intent Parsing (The Plan)**
#
# The Broker receives the user's natural language and converts it into a structured Execution Plan.
#
# **Phase 2: Agent Execution (The Work)**
#
# The Broker sends requests to the agents.
#     - Market Scout Response
#     - Revenue Strategist Response
#     - Content Response
#
# **Phase 3: Broker Synthesis (The Solution)**
#
# The Broker aggregates the above responses into a final strategic plan. This is used to generate the natural language response for the user and prepare the API calls if the user says "Yes".
#
# ### How does this deliver value ###
#
# By structuring the agentic network this way, the network is:
#
# **Auditable:** You can see exactly why the broker recommended a price drop (because of the event_change_detected logic).
#
# **Actionable:** The JSON in Phase 3 is ready to be sent to the Ofishal API (PUT /rates, PUT /content) the moment the user approves.
#
# **Modular:** You can swap out the "Revenue Agent" for a different model or provider without breaking the Broker's logic.

# %% [markdown]
# # Business Value Summary
#
# | Feature | Old Way (Manual) | New Way (Agentic Network) | Value |
# | --- | --- | --- | --- |
# | **Crisis Response** | Partner sees low bookings,<br>guesses why, manually checks<br>3 tools. | Broker Identifies event shift,<br>correlates with pricing, suggest fix<br>instantly | **Speed to Market** |
# | **Content Management** | Static photo sit for months;<br>manual updates. | Agent swaps photos based on<br>season/weather automatically. | **Conversion Lift** |
# | **Reviews** | Generic "copy/paste"<br>responses or ignored reviews. | AI drafts hyper-personalized<br>responses referencing specific<br>operational fixes. | **Brand Loyalty** |

# %% [markdown]
# # Running it
#
# Everything above is the design. Below it actually runs.
#
# **What is real and what is not.** The orchestration is real: the LangGraph state machine, the
# LLM-driven routing, the synthesis step, the risk score and the human approval gate all execute.
# **Every agent response is a fixture read from the XML config.** No vendor API is called, and no
# MCP server exists yet. That keeps the demo deterministic and nearly free to run, and swapping a
# fixture for a real call is a one-function change.

# %% [markdown]
# ## Setup

# %%
# On Colab this clones the repo so the package is importable. Locally it does nothing.
import sys, os, subprocess
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    if not Path("fisher-agentic-network-langgraph").exists():
        subprocess.run(["git", "clone", "-q",
            "https://github.com/johnfisher-ai/fisher-agentic-network-langgraph.git"], check=True)
    os.chdir("fisher-agentic-network-langgraph")
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # Running from notebooks/ inside a clone: step up to the repo root.
    if Path("../config").is_dir():
        os.chdir("..")

print("working directory:", Path.cwd().name)
print("config files:", sorted(p.name for p in Path("config").glob("*.xml")))
# Out:
# working directory: site
# config files: ['config_agency.xml', 'config_travel.xml']

# %% [markdown]
# ### The API key
#
# The key is read from the environment, never written in a cell. Provide it one of three ways:
#
# - **Locally:** a `.env` file in the repo root containing `OPENAI_API_KEY=sk-...`. It is
#   git-ignored. Copy `.env.example` to start.
# - **Colab:** the key icon in the left sidebar, secret named `OPENAI_API_KEY`.
# - **Any shell:** `export OPENAI_API_KEY=sk-...`
#
# Running the network costs a fraction of a cent per question: two `gpt-4o` calls, one to route
# and one to synthesise.

# %%
from agentic_network.cli import load_env
load_env()

if IN_COLAB and not os.environ.get("OPENAI_API_KEY"):
    from google.colab import userdata
    os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

key = os.environ.get("OPENAI_API_KEY")
assert key, "OPENAI_API_KEY is not set. See the three options above."
print(f"key loaded: {key[:11]}...{key[-4:]}")   # never print a key in full
# Out:
# key loaded: sk-proj-9ah..._I0A
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %% [markdown]
# ## Build the network
#
# Three lines. The roster, the prompts and the fixtures all come from the XML.

# %%
from agentic_network import load_config, build_network, ConsoleChannel

config  = load_config("config/config_travel.xml")
network = build_network(config, channel=ConsoleChannel(verbose=True, auto_approve=True))

print(f"{len(config.agents)} agents loaded from config/config_travel.xml:")
for a in config.agents.values():
    print(f"  {a.id:20s} {a.name:22s} {a.description}")
# Out:
# 5 agents loaded from config/config_travel.xml:
#   market_scout         Market Scout           events, weather
#   revenue_strategist   Revenue Strategist     pricing, rates
#   content_specialist   Content Specialist     photos, description
#   guest_experience     Guest Experience       reviews, sentiment
#   facilities_manager   Facilities Manager     maintenance, housekeeping, physical inventory

# %% [markdown]
# `auto_approve=True` answers the human gate without prompting, so the notebook runs top to
# bottom unattended. Set it to `None` to be asked, or `False` to reject everything. The desktop
# GUI asks a real person.

# %% [markdown]
# # Travel partner examples

# %% [markdown]
# ### Example 1: the November slump

# %%
network.run('My bookings for November are down 20%. Diagnose this.')
# Out:
# [trace]  scenario 1 selected for: 'My bookings for November are down 20%. Diagnose this.'
# [status] Analysing intent ...
# [status] Delegating to market_scout, revenue_strategist
# [status] Consulting Market Scout ...
# [trace]  Market Scout returned: {"event": "Tech Summit", "status": "CANCELLED", "impact": "negative demand"}
# [status] Consulting Revenue Strategist ...
# [trace]  Revenue Strategist returned: {"your_rate": 250, "comp_rate": 200, "variance": "Drop rate by $50", "recommendation": "Drop Rate"}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=True
# [status] Waiting for human approval ...
# [trace]  proposal put to a human:
# ...

# %% [markdown]
# ### Example 2: noise complaints

# %%
network.run("I'm getting bad reviews about noise. What is happening?")
# Out:
# [trace]  scenario 2 selected for: "I'm getting bad reviews about noise. What is happening?"
# [status] Analysing intent ...
# [status] Delegating to guest_experience, facilities_manager
# [status] Consulting Facilities Manager ...
# [trace]  Facilities Manager returned: {"alert": "External noise high", "action_recommended": "Place complimentary earplugs and apology notes in street-facing rooms."}
# [status] Consulting Guest Experience ...
# [trace]  Guest Experience returned: {"sentiment": "Negative", "keywords": ["Noise", "Drilling", "Early Morning"]}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=False
# It seems that guests are experiencing issues with noise, particularly related to drilling and early morning disturbances. The Facilities Manager has identified that external noise levels are high and recommends placing complimentary earplugs and apology notes in street-facing rooms to address the issue.
#
# DETERMINE RISK: RISK: NO
# ...

# %% [markdown]
# ### Example 3: a viral event

# %%
network.run('Is there a concert coming up? Demand is weird.')
# Out:
# [trace]  scenario 3 selected for: 'Is there a concert coming up? Demand is weird.'
# [status] Analysing intent ...
# [status] Delegating to market_scout
# [status] Consulting Market Scout ...
# [trace]  Market Scout returned: {"event": "Taylor Swift Eras Tour", "status": "NEW_ANNOUNCEMENT", "impact": "massive demand spike"}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=False
# Yes, there is a concert coming up. The "Taylor Swift Eras Tour" has been newly announced, and it is experiencing a massive demand spike.
#
# RISK: NO
# [status] Ready
# 'Yes, there is a concert coming up. The "Taylor Swift Eras Tour" has been newly announced, and it is experiencing a massive demand spike.\n\nRISK: NO'

# %% [markdown]
# ### Example 4: attracting families

# %%
network.run('How do I attract more families for summer?')
# Out:
# [trace]  scenario 4 selected for: 'How do I attract more families for summer?'
# [status] Analysing intent ...
# [status] Delegating to market_scout, content_specialist, revenue_strategist
# [status] Consulting Content Specialist ...
# [trace]  Content Specialist returned: {"action": "Add amenity: Cribs", "detail": "Tag as an amenity so the listing appears in family filters"}
# [status] Consulting Revenue Strategist ...
# [trace]  Revenue Strategist returned: {"opportunity": "Multi-room bookings", "recommendation": "Create Family Package"}
# [status] Consulting Market Scout ...
# [trace]  Market Scout returned: {"demographic": "Families", "flight_capacity": "+20%", "origin": "Domestic"}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=True
# [status] Waiting for human approval ...
# [trace]  proposal put to a human:
# To attract more families for the summer, consider implementing the following strategies based on the data:
#
# ...

# %% [markdown]
# ### Example 5: a competitor price war

# %%
network.run('Why am I losing share? Are my prices okay?')
# Out:
# [trace]  scenario 5 selected for: 'Why am I losing share? Are my prices okay?'
# [status] Analysing intent ...
# [status] Delegating to revenue_strategist
# [status] Consulting Revenue Strategist ...
# [trace]  Revenue Strategist returned: {"alert": "Price War", "comp_move": "-$30 drop", "recommendation": "Match competitor rate or add value"}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=True
# [status] Waiting for human approval ...
# [trace]  proposal put to a human:
# 1. You are losing market share due to a price war. A competitor has dropped their prices by $30, which may be affecting your sales. It is recommended to either match the competitor's rate or add additional value to your offering to remain competitive.
#
# 2. RISK: YES
#
# ...
# HUMAN APPROVAL REQUIRED
# ...

# %% [markdown]
# ### Example 6: pure analysis, no approval needed

# %%
network.run('Check the recent guest reviews and tell me the general sentiment.')
# Out:
# [trace]  scenario 1 selected for: 'Check the recent guest reviews and tell me the general sentiment.'
# [status] Analysing intent ...
# [status] Delegating to guest_experience
# [status] Consulting Guest Experience ...
# [trace]  Guest Experience returned: {"sentiment": "Neutral", "recent_issues": "None"}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=False
# The general sentiment of the recent guest reviews is neutral, and there have been no recent issues reported.
#
# RISK: NO
# [status] Ready
# 'The general sentiment of the recent guest reviews is neutral, and there have been no recent issues reported.\n\nRISK: NO'

# %% [markdown]
# ### Example 7: physical inventory

# %%
network.run('We have a lot of families checking in this weekend. Do we have enough cribs?')
# Out:
# [trace]  scenario 4 selected for: 'We have a lot of families checking in this weekend. Do we have enough cribs?'
# [status] Analysing intent ...
# [status] Delegating to facilities_manager
# [status] Consulting Facilities Manager ...
# [trace]  Facilities Manager returned: {"inventory_check": "Cribs and rollaway beds", "in_use": 2, "available": 8, "status": "sufficient"}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=False
# 1. Yes, we have enough cribs available for the weekend. Currently, there are 8 cribs available, with 2 already in use.
#
# 2. DETERMINE RISK: RISK: NO
# [status] Ready
# '1. Yes, we have enough cribs available for the weekend. Currently, there are 8 cribs available, with 2 already in use.\n\n2. DETERMINE RISK: RISK: NO'

# %% [markdown]
# ### Example 8: rejecting the proposal
#
# The same kind of question, with the human saying no. The network reports the cancellation and
# does not act. Note that the text put to the human is the text that comes back: the approval gate
# returns the proposal verbatim rather than regenerating it.

# %%
rejecting = build_network(config, channel=ConsoleChannel(auto_approve=False))
rejecting.run("My competitor dropped their rates. Should I match them?")
# Out:
# ...
# HUMAN APPROVAL REQUIRED
# ...
# Based on the data, your competitor has dropped their rates by $30. The recommendation is to either match the competitor's rate or add value to your offering to remain competitive.
#
# RISK: YES
# ...
# (auto_approve=False: rejected without prompting)
# ACTION CANCELLED. The human operator rejected the proposal.
#
# What was proposed:
# Based on the data, your competitor has dropped their rates by $30. The recommendation is to either match the competitor's rate or add value to your offering to remain competitive.
#
# RISK: YES
# "ACTION CANCELLED. The human operator rejected the proposal.\n\nWhat was proposed:\nBased on the data, your competitor has dropped their rates by $30. The recommendation is to either match the competitor's rate or add value to your offering to remain competitive. \n\nRISK: YES"

# %% [markdown]
# # The same code, a different business
#
# Nothing below changes the graph, the nodes or the routing logic. Only the config file changes.
# `config_agency.xml` describes a management consulting firm: five different specialists, a
# different router prompt, and a risk rule about layoffs and large budget moves instead of one
# about prices and published content.

# %%
agency = load_config("config/config_agency.xml")
agency_net = build_network(agency, channel=ConsoleChannel(verbose=True, auto_approve=True))

print(f"{len(agency.agents)} agents loaded from config/config_agency.xml:")
for a in agency.agents.values():
    print(f"  {a.id:22s} {a.name:30s} {a.description}")
# Out:
# 5 agents loaded from config/config_agency.xml:
#   market_analyst         Market Intelligence Analyst    Competitor moves, industry trends, macroeconomics, market share.
#   financial_modeler      Financial Modeler              Revenue projections, cost analysis, margin impact, ROI calculations.
#   org_strategist         Organizational Strategist      Workforce planning, change management, leadership, restructuring.
#   operations_specialist  Operations Specialist          Supply chain efficiency, process optimization, technology/ERP adoption.
#   risk_compliance        Risk & Compliance Officer      Regulatory changes, legal risks, PR impact, data privacy.

# %% [markdown]
# ### Supply chain disruption

# %%
agency_net.run('Our client has massive supply chain delays from overseas suppliers. How should we advise them?')
# Out:
# [trace]  scenario 1 selected for: 'Our client has massive supply chain delays from overseas suppliers. How should we advise them?'
# [status] Analysing intent ...
# [status] Delegating to operations_specialist
# [status] Consulting Operations Specialist ...
# [trace]  Operations Specialist returned: {"bottleneck": "Tier-1 Suppliers", "action": "Activate secondary suppliers in LATAM to bypass current port congestion."}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=False
# **Executive-Level Consulting Recommendation:**
#
# Given the significant supply chain delays from overseas suppliers, it is crucial to implement a strategic approach to mitigate these disruptions and ensure continuity in operations. Our analysis indicates that the primary bottleneck is with Tier-1 suppliers, exacerbated by current port congestion. To address this, we recommend the following actions:
#
# 1. **Activate Secondary Suppliers in LATAM**:
# ...

# %% [markdown]
# ### Post-merger integration
#
# This one recommends headcount reductions, so the risk rule stops it for a human.

# %%
agency_net.run('We are advising on a post-merger integration. Where can we find synergies?')
# Out:
# [trace]  scenario 3 selected for: 'We are advising on a post-merger integration. Where can we find synergies?'
# [status] Analysing intent ...
# [status] Delegating to org_strategist, operations_specialist
# [status] Consulting Operations Specialist ...
# [trace]  Operations Specialist returned: {"integration": "ERP Systems", "action": "Migrate acquired company onto the parent instance of SAP within 90 days."}
# [status] Consulting Organizational Strategist ...
# [trace]  Organizational Strategist returned: {"action": "Restructuring", "impact": "10% headcount reduction in overlapping departments.", "recommendation": "Draft severance packages and retention bonuses for key personnel."}
# [status] Synthesising and scoring risk ...
# [trace]  synthesis complete, requires_approval=True
# [status] Waiting for human approval ...
# [trace]  proposal put to a human:
# **Executive-Level Consulting Recommendation:**
#
# ...

# %% [markdown]
# # How scenarios are chosen
#
# Each config lists scenarios with keywords. A question is matched against them in order, and the
# first hit wins. Keywords match on **word boundaries with an optional plural**, so `crib` matches
# "cribs" while `ai` no longer matches *retail*, *explain* or *email*. An earlier substring version
# routed all three to the wrong scenario without any sign that it had.

# %%
probes = [
    ("My bookings for November are down",     config),
    ("There is construction noise outside",   config),
    ("Do we have enough cribs this weekend?", config),
    ("What is our retail strategy?",          agency),
    ("Please explain the situation",          agency),
    ("A competitor launched an AI product",   agency),
]
for text, cfg in probes:
    print(f"  scenario {cfg.scenario_for(text)}   {text}")
# Out:
#   scenario 1   My bookings for November are down
#   scenario 2   There is construction noise outside
#   scenario 4   Do we have enough cribs this weekend?
#   scenario 1   What is our retail strategy?
#   scenario 1   Please explain the situation
#   scenario 2   A competitor launched an AI product

# %% [markdown]
# # The desktop client
#
# There is also a tkinter desktop app, with a chat pane and a live agent trace log, where the
# approval gate is answered by a real person:
#
# ```
# python3 -m agentic_network.gui
# python3 -m agentic_network.gui --config config/config_agency.xml
# ```
#
# **It does not run here.** tkinter needs a display, which Colab does not have, so this notebook
# uses the headless path throughout. Running the GUI in Colab fails; running it in a local Jupyter
# session opens a window and blocks until you close it.
